# %%
# Importing the necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns  # Visualization
import matplotlib.pyplot as plt  # Visualization
# %matplotlib inline
sns.set(color_codes=True)
from scipy import stats
import warnings
warnings.filterwarnings("ignore")

# Load the dataset into a DataFrame with the correct file path
file_path = r"C:\Users\kunal\OneDrive\Desktop\pythanwork\Cars_data.csv"
df = pd.read_csv(file_path)

# Print the first 5 rows of the DataFrame
print(df.head())

# Check the data types of each column
print(df.info())

# Dropping irrelevant columns
cols_to_drop = ["Engine Fuel Type", "Market Category", "Vehicle Style", "Popularity", "Number of Doors", "Vehicle Size"]
df = df.drop(columns=cols_to_drop)

# Print the DataFrame after dropping columns
print(df.head())

# Renaming the columns
rename_cols = {
    "Make": "Brand",
    "Engine HP": "Horsepower",
    "Engine Cylinders": "Cylinders",
    "Transmission Type": "Transmission",
    "Driven_Wheels": "Drive Mode",
    "highway MPG": "Highway MPG",
    "city mpg": "City MPG",
    "MSRP": "Price"
}
df.rename(columns=rename_cols, inplace=True)

# Print the DataFrame after renaming
print(df.head())

# Dropping duplicate rows
print(f"Number of rows before removing duplicates: {df.shape[0]}")
df.drop_duplicates(inplace=True)
print(f"Number of rows after removing duplicates: {df.shape[0]}")

# Checking for missing values
print(df.isnull().sum())

# Dropping missing values
df.dropna(inplace=True)

# Verifying if missing values are removed
print(df.isnull().sum())

# Descriptive statistics of the DataFrame
print(df.describe())

# Descriptive statistics of the DataFrame
print(df.describe())
# Identify and remove outliers using IQR
Q1 = numeric_cols.quantile(0.25)
Q3 = numeric_cols.quantile(0.75)
IQR = Q3 - Q1
mask = ~((numeric_cols < (Q1 - 1.5 * IQR)) | (numeric_cols > (Q3 + 1.5 * IQR))).any(axis=1)
df_cleaned = df[mask]

# Print shape before and after outlier removal
print(f"\nOriginal shape: {df.shape}")
print(f"Shape after removing outliers: {df_cleaned.shape}")

# Box Plot of Numeric Features
plt.figure(figsize=(10, 5))
sns.boxplot(data=df_cleaned[numeric_cols.columns])
plt.title("Box Plot of Numeric Features After Outlier Removal")
plt.xticks(rotation=45)
plt.show()

# Correlation Heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(df_cleaned[numeric_cols.columns].corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# Save cleaned dataset
cleaned_file_path = r"C:\Users\kunal\OneDrive\Desktop\pythanwork\Cars_data_cleaned.csv"
df_cleaned.to_csv(cleaned_file_path, index=False)

print("\nData cleaning and visualization completed successfully!")
print(f"Cleaned dataset saved at: {cleaned_file_path}")
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
# Out:
# Dataset Preview:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...
